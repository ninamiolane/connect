# %%
"""Data inspection."""
# Out:
# 'Data inspection.'

# %%
import glob
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
from scipy import signal

import warnings
warnings.filterwarnings("ignore")

ELECTRODE_ID = 1
data_file = f'2018-05-31_15-43-39/CSC{ELECTRODE_ID}.ncs'

# %%
# Config parameters:
ops_fs = 32000 # sampling rate s^-1

ops_lowcut = 600 # Hz
ops_highcut = 7000 # Hz
ops_delta = 100

ops_cheby_order = 6
ops_cheby_passband_ripple = 0.01

ops_fir_order = 50

ops_min_consecutive = 5
ops_flat_window = 100

ops_spike_threshold = 3.1 # spike threshold in standard deviations
ops_clip = 30 # Peak window in terms of number of samples, not ms!

ops_nyq = np.float64(ops_fs / 2)

# %%
# Get Data
header_size = 16 * 1024

with open(data_file, 'rb') as fid:
    fid.seek(header_size)

    # Read data according to Neuralynx information
    data_format = np.dtype([
        ('TimeStamp', np.uint64),
        ('ChannelNumber', np.uint32),
        ('SampleFreq', np.uint32),
        ('NumValidSamples', np.uint32),
        ('Samples', np.int16, 512)])
    raw = np.fromfile(fid, dtype=data_format)

# %%
# Inspect Data
print(raw.shape)
print(raw.dtype)

# Look at a field - each field is a usual ndarray
print(raw['SampleFreq'])  # Good: the sample frequency is the same everywhere: 32000Hz
print(raw['SampleFreq'].shape)  # ?: shape is (50863,)

# Look at Channel Number
print(raw['ChannelNumber'])  # ?: ChannelNumber is 0 everywhere
print(raw['ChannelNumber'].shape)

# Look at TimeStamp
print(raw['TimeStamp'])  # ?: In which units are the timestamps?
print(raw['TimeStamp'].shape)
# Out:
# (50863,)
# [('TimeStamp', '<u8'), ('ChannelNumber', '<u4'), ('SampleFreq', '<u4'), ('NumValidSamples', '<u4'), ('Samples', '<i2', (512,))]
# [32000 32000 32000 ... 32000 32000 32000]
# (50863,)
# [0 0 0 ... 0 0 0]
# (50863,)
# [104904552095 104904568095 104904584095 ... 105717896269 105717912269
#  105717928269]
# (50863,)

# %%
# Look at the Samples
print(raw['Samples'])
print(raw['Samples'].shape)  # ?: shape is (50863, 512): what is 512?
# Out:
# [[  977  1192  1241 ...  1837  2042  2082]
#  [ 1704  1230  1031 ...   102   189   610]
#  [  498   309   418 ...  1041  1193  1127]
#  ...
#  [-2309 -2573 -2721 ... -2265 -2348 -2373]
#  [-2466 -2587 -2486 ...  4063  4096  4069]
#  [ 4258  4316  4192 ...  4063  4096  4069]]
# (50863, 512)

# %%
# Plot first secs of this electrode
def plot_samples(data, n_ms, title=''):
    n_secs = 0.001 * n_ms
    # Determine duration of recording in seconds
    dur_sec = data.shape[0] / sf
    time = np.linspace(0, dur_sec, data.shape[0])
    # Plot first second of data
    fig, ax = plt.subplots(figsize=(15, 5))
    
    last_time = int(round(n_secs*sf))
    
    ax.plot(1000*time[0:last_time], data[0:last_time])
    ax.set_title(title + 'Sampling Frequency: {}Hz'.format(sf),
                 fontsize=23)
    ax.set_xlim(0, 1000*time[last_time])
    ax.set_xlabel('time [ms]', fontsize=20)
    ax.set_ylabel('amplitude [uV]', fontsize=20)
    plt.show()
    
samples_orig = raw['Samples']
samples = samples.ravel()

# Works with and without ravel
plot_samples(samples_orig, 10, title='Original Data with 512 dims; ')
plot_samples(samples, 10, title='Original Data - Ravel; ')

# %%
def filter_passband(samples, low=500, high=9000, sf=-1, order=2):
    """ 
    Filter from tutorial: 
    https://towardsdatascience.com/using-signal-processing-to-extract-neural-events-in-python-964437dc7c0
    to remove 60Hz that correspond to electronics.
    """
    # Set bands
    low = low / ops_nyq
    high = high / ops_nyq
    # Calculate coefficients
    b, a = signal.butter(order, [low, high], btype='band')
    # Filter signal
    filtered_samples = signal.lfilter(b, a, samples)
    return filtered_samples

# Apply only this filter to raw data
samples_passband = filter_passband(samples, sf=ops_fs)
plot_samples(samples_passband, 10)

# %%
def filter_cheby(samples):
    """
    First filter applied by Eric, in matlab code from Archive.zip.
    IIR cuts low frequencies with a sharp filter.
    Note: Similar to the passband filter from the tutorial.
    """
    filter_order = ops_cheby_order
    max_ripple = ops_cheby_passband_ripple
    critical_frequencies = [ops_lowcut - 4 * ops_delta, ops_highcut + 4 * ops_delta] / ops_nyq

    b0, a0 = signal.cheby1(
        N=filter_order, 
        rp=max_ripple,
        Wn=critical_frequencies, 
        btype='bandpass')
    filtered_samples = signal.filtfilt(b0, a0, samples)
    return filtered_samples

# Apply only this filter to raw data
samples_cheby = filter_cheby(samples)
plot_samples(samples_cheby, 10, 'After Cheby Filter; ')

# %%
def filter_firwin(samples):
    """
    Second filter applied by Eric, in matlab code from Archive.zip.
    Low order Hann Filter.
    
    Rmk: Length of the filter = number of coefficients, i.e. the filter order + 1.
    """
    filter_length = ops_fir_order + 1 
    cutoff_frequencies = [ops_lowcut - ops_delta, ops_highcut + ops_delta] / ops_nyq
    b1 = signal.firwin(
        numtaps=filter_length,
        cutoff=cutoff_frequencies, 
        window='hann')
    beq = np.convolve(b1, b1) # 2 stage filter
    
    # Applying filters, with 0 phase lag
    filtered_samples = signal.filtfilt(beq, 1, samples)
    return filtered_samples

samples_firwin = filter_firwin(samples_cheby)
plot_samples(samples_firwin, 10, 'After FIR Filter; ')

# %%
# Consecutive filters on same graph
plot_samples(samples, 100, title='Original Data; ')
plot_samples(samples_cheby, 100, title='After Cheby Filter; ')
plot_samples(samples_firwin, 100, title='After FIR Filter; ')

# %%
def remove_extreme_amplitudes(samples):
    """
    From Eric's code in Archive.
    Removing the data above 90% of the extremum values.
    """
    min_amplitude = np.min(samples)
    max_amplitude = np.max(samples)
    interval = np.array([min_amplitude, max_amplitude])

    valid_interval = interval * 0.90

    low_bool = samples <= valid_interval[0]
    high_bool = samples >= valid_interval[1]
    
    bad_amplitudes_mask = np.logical_or(low_bool, high_bool)
    # print(sum(bad_amplitudes_mask))

    filtered_samples = samples
    filtered_samples[bad_amplitudes_mask] = np.nan
    return filtered_samples

samples_no_extreme = remove_extreme_amplitudes(samples_firwin)
plot_samples(samples_no_extreme, n_ms=100, title='No Extreme Amplitude;')

# %%
def test_remove_extreme_amplitudes():
    test_samples = np.array([-0.1, 0.1, -0.2, 10, -10, 0.2])
    result = remove_extreme_amplitudes(test_samples)
    expected = np.array([-0.1, 0.1, -0.2, np.nan, np.nan, 0.2])
    print(result)
    print(expected)
    
test_remove_extreme_amplitudes()
# Out:
# [-0.1  0.1 -0.2  nan  nan  0.2]
# [-0.1  0.1 -0.2  nan  nan  0.2]

# %%
def consecutive_integers(integers, min_consecutive):
    consec = {}    
    counter = 0
    idx = 0
    
    while (idx < len(integers)):
        start_integer = integers[idx]
        
        while (integers[idx+1] == integers[idx] + 1):
            idx += 1
            if idx == len(integers)-1:
                break
        
        end_integer = integers[idx]
        
        if end_integer - start_integer >= min_consecutive:
            consec[counter] = {}
            consec[counter]['start_integer'] = start_integer
            consec[counter]['end_integer'] = end_integer
            counter += 1
    
        idx += 1
    return consec

# %%
def test_consecutive_integers():
    test_integers = np.array([0, 3, 4, 7, 8, 11, 3, 4, 55, 56, 57, 58])
    test_min_consecutive = 1
    result = consecutive_integers(test_integers, test_min_consecutive)
    print(result)
test_consecutive_integers()
# Out:
# {0: {'start_integer': 3, 'end_integer': 4}, 1: {'start_integer': 7, 'end_integer': 8}, 2: {'start_integer': 3, 'end_integer': 4}, 3: {'start_integer': 55, 'end_integer': 58}}

# %%
def get_flat_ids(original_samples, channel_id=0):
    slopes = np.diff(original_samples, axis=0)
    #print(slopes.shape)
    #print(slopes)
    
    # Find indices where the signal is flat from a time point to the next
    slope0_ids = np.where(slopes==0)[0]  # Nothing is flat?!
    #print(slope0_ids.shape)
    #print(slope0_ids)

    # Look for time intervals between flatnesses
    diff_slope0_ids = np.diff(slope0_ids, axis=0)
    #print(diff_ids)
    flat_ids = np.where(diff_slope0_ids==1)[0]  # Not sure this is needed?
   # print(flat_ids)
    return flat_ids, slope0_ids

# %%
def test_get_flat_ids():
    print('test')
    test_samples = np.array([1, 2, 3, 3, 5, 6, 7, 8, 8])
    result, _ = get_flat_ids(test_samples)
    expected = np.array([2, 7])
    print(result)
    
    print('test')
    test_samples = np.array([1, 2, 3, 3, 3, 6, 8, 8, 8])
    result, _ = get_flat_ids(test_samples)
    expected = np.array([2, 7])
    print(result)
test_get_flat_ids()
# Out:
# test
# []
# test
# [0 2]

# %%
# TODO(nina): Understand what is going on here -  Skip for now

# Assuming channels are electrodes
# TODO(nina): right now channel_id is not used
def remove_flat_regions(samples, channel_id=0):
    """
    From Eric's code in Archive.
    Removing data around flat regions of the raw data.
    """   
    # Where it is flat and we can remove altogether
    flat_ids, slope0_ids = get_flat_ids(samples)
    consecutives = consecutive_integers(flat_ids, ops_min_consecutive)
    print('consecutives')
    print(consecutives)
    print('slope0_ids')
    print(slope0_ids)
    filtered_samples = samples
    for _, consecutive in consecutives.items(): 
        # Each block of flat thing to remove
        print('cons')
        print(consecutive)
        start_slope0_id = consecutive['start_integer']
        start_idx = slope0_ids[start_slope0_id] #1

        start_idx = np.max([0, start_idx - ops_flat_window])  # Add window
        
        end_idx = slope0_ids[consecutive['end_integer']] 
        end_idx = np.min([num_samples+1, end_idx + ops_flat_window])  # Add window
        print('start and end')
        print(start_idx)
        print(end_idx)
        # TODO(nina): Problem with nan?
        filtered_samples[start_idx:end_idx+1] = np.nan  # 666

    nanmean = np.nanmean(filtered_samples)
    nanstd = np.nanstd(filtered_samples)
    filtered_samples = (filtered_samples - nanmean) / nanstd
    return filtered_samples

samples_no_flat = remove_flat_regions(samples_no_extreme)
plot_samples(samples_no_flat, 100, 'No Flat; ')
# Out:
# consecutives
# {}
# slope0_ids
# []

# %%
def test_remove_flat_regions():
    print('\ntest with not enough consecutives flatness')
    test_samples = np.array([1, 2, 2, 2, 2, 2, 2, 2, 5, 6, 7, 7, 7, 8, 8, 9, 9, 9, 9])
    result = remove_flat_regions(test_samples)
    print(result)
    
    print('\ntest with enough consecutives flatness')
    test_samples = np.array([1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 7, 7, 7, 8, 8, 9, 9, 9, 9])
    result = remove_flat_regions(test_samples)
    print(result)
test_remove_flat_regions()
# Out:
# test with not enough consecutives flatness
# consecutives
# {}
# slope0_ids
# [ 1  2  3  4  5  6 10 11 13 15 16 17]
# [1 2 2 2 2 2 2 2 5 6 7 7 7 8 8 9 9 9 9]
#
# test with enough consecutives flatness
# consecutives
# {0: {'start_integer': 0, 'end_integer': 6}}
# slope0_ids
# [ 1  2  3  4  5  6  7  8 10 11 13 15 16 17]
# cons
# {'start_integer': 0, 'end_integer': 6}
# start and end
# 1
# 7
# [  1 666 666 666 666 666 666 666   2   2   7   7   7   8   8   9   9   9
#    9]

# %%
def mad(data, axis=None):
    return np.mean(np.absolute(data - np.mean(data, axis)), axis)

# %%
def find_minima(samples, threshold, channel_id=0):
    """ 
    %% Finds peaks in our data
    % Code based from Abdul's code &
    https://www.frontiersin.org/articles/10.3389/fnins.2016.00537/full

    Peaks are defined as minima threshold*std away from 0
    Returns: 1 if there is a peak, 0 if not
    """
    # Estimate std from the MAD more robust to noise
    num_samples = len(samples)
    std = 1.4826 * mad(samples)
    
    thresh_mat = - threshold * std * np.ones(num_samples - 2)
    
    slopes = np.diff(samples, axis=0)
    
    bool_neg = slopes[:-1] < 0
    bool_pos = slopes[1:] > 0
    bool_thres = samples[1:-1] < thresh_mat
    print(sum(bool_thres))

    minima = np.logical_and(bool_neg, bool_pos)
    minima = np.logical_and(minima, bool_thres)
    minima = minima.astype(int)
    print(minima.shape)
    # Pad it back to get the same shape like data
    false = np.array([False])
    minima = np.concatenate([false, minima, false])
    print(sum(minima))  # Note: this finds 0 minima
    return minima

# %%
def get_peak_data(samples, threshold):
    peak_data = {}

    peaks_mask = find_minima(samples, threshold)
    peak_ids = np.where(peaks_mask)[0]

    for i, peak_id in enumerate(peak_ids):     
        amplitude = samples[peak_id]
        peak_data[i]['global_loc'] = peak_id
        peak_data[i]['amplitude'] = amplitude
        
    return peak_data

# %%
peak_data = get_peak_data(samples_no_extreme, ops_spike_threshold)
peak_data
# Out:
# 0
# (26041854,)
# 0
# {}

# %%
# Get nvt Data
# https://neuralynx.com/software/NeuralynxDataFileFormats.pdf
# All files contain a 16 kilobyte ASCII text header. 
header_size = 16 * 1024
nvt_file = '2018-05-31_15-43-39/VT1.nvt'
with open(nvt_file, 'rb') as fid:
    fid.seek(header_size)

    # Read data according to Neuralynx information
    data_format = np.dtype([
        ('stx', np.uint16),
        ('id', np.uint16),
        ('data_size', np.uint16),
        ('TimeStamp', np.uint64), # in um
        ('Points', np.uint32, 400),
        ('nrc', np.int16),  # Unused
        ('extracted_x', np.int32),
        ('extracted_y', np.int32),
        ('extracted_angle', np.int32),
        ('targets', np.int32, 50),
    ])
    nvt_raw = np.fromfile(fid, dtype=data_format)

# %%
len(nvt_raw['TimeStamp'])  # Less time steps than raw data?
# Out:
# 48807

# %%
len(nvt_raw['extracted_x'])
# Out:
# 48807

# %%
nvt_raw['extracted_x'][:10]
# Out:
# array([23724032,        0,        0,        0,        0,        0,
#               0,        0,        0,        0], dtype=int32)
